# %%
pip install chatterbot==1.0.4
# Out:
# ...
#   Using cached ChatterBot-1.0.4-py2.py3-none-any.whl (66 kB)
# ...
#   Using cached mathparse-0.1.2-py3-none-any.whl (7.2 kB)
# ...
#   Using cached Pint-0.22-py3-none-any.whl (294 kB)
# ...
#   Using cached python_dateutil-2.7.5-py2.py3-none-any.whl (225 kB)
# ...
#   Using cached chatterbot_corpus-1.2.0-py2.py3-none-any.whl (117 kB)
# ...
#   Using cached SQLAlchemy-1.2.19.tar.gz (5.7 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached PyYAML-3.13.tar.gz (270 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.2.19-cp39-cp39-win_amd64.whl size=1114240 sha256=3bc881a716b030e5105404f8c820d20bdec9b9d89fd32da9a29717c7df119b73
#   Stored in directory: c:\users\harsh\appdata\local\pip\cache\wheels\12\75\ee\52355e3658b18c812a419a7fdf581ab885b01c0675e25e9b01
# ...

# %%
pip install -U PyYaml==3.12
# Out:
# ...
#      ------------------------------------- 375.8/375.8 kB 11.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for PyYaml: filename=PyYAML-3.12-cp39-cp39-win_amd64.whl size=43067 sha256=3f49cb0cef88b0a0a898e790bd95091159880c94c01e37d678c93851b740525e
#   Stored in directory: c:\users\harsh\appdata\local\pip\cache\wheels\d2\35\d6\9853325318cff4c6fee7514905a5931993a2230e2b746fc978
# Successfully built PyYaml
# ...
#   Attempting uninstall: PyYaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
import time
time.clock = time.time

# %%
import collections.abc
collections.Hashable = collections.abc.Hashable

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer, ListTrainer

# Create a new chatbot instance
chatbot = ChatBot("CollegeAdmissionBot")

# Create a new trainer for the chatbot
trainer = ChatterBotCorpusTrainer(chatbot)

# Train the chatbot using the English corpus
trainer.train("chatterbot.corpus.english")

# Optionally, you can train the chatbot using custom data
trainer = ListTrainer(chatbot)
trainer.train([
    "What courses are offered?",
    "We offer courses in Computer Science, Electrical Engineering, and Mechanical Engineering.",
    "Tell me about the Computer Science course.",
    "The Computer Science course covers subjects like programming, data structures, and artificial intelligence.",
    "What is the syllabus for Electrical Engineering?",
    "The syllabus for Electrical Engineering includes subjects like circuit analysis, digital electronics, and power systems.",
    "How much are the fees for Mechanical Engineering?",
    "The fees for Mechanical Engineering are $9,000.",
    "Who are the faculties for Computer Science?",
    "The faculties for Computer Science are ABC and DEF.",
    "What are the admission requirements for Electrical Engineering?",
    "The admission requirements for Electrical Engineering include a minimum GPA of 5.5, SAT/ACT scores, and recommendation letters.",
    "What is the contact information for the college?",
    "The contact information for the college is as follows: Phone: 123456789, Email: info@examplecollege.edu, Address: 123 College, City, State, Country.",
    "Tell me more about the Mechanical Engineering course.",
    "The Mechanical Engineering course covers subjects like thermodynamics, mechanics of materials, and fluid mechanics.",
    "What are the prerequisites for the Computer Science course?",
    "The prerequisites for the Computer Science course include a strong foundation in mathematics and programming knowledge.",
    "How can I apply for admission?",
    "To apply for admission, you need to fill out an application form, submit required documents, and meet the admission requirements of the chosen course.",
    "What extracurricular activities are available at the college?",
    "The college offers a range of extracurricular activities including clubs, sports teams, and cultural events.",
    "Tell me about the career prospects for Electrical Engineering graduates.",
    "Electrical Engineering graduates have opportunities in industries such as power systems, telecommunications, and electronics.",
    "What is the duration of the Computer Science course?",
    "The duration of the Computer Science course is four years.",
    "What research opportunities are available for students?",
    "Students have the opportunity to participate in research projects under the guidance of faculty members.",
    "What scholarships are available for students?",
    "The college offers various scholarships based on academic merit, financial need, and other criteria.",
    "Tell me about the campus facilities.",
    "The campus facilities include state-of-the-art classrooms, laboratories, a library, and recreational areas.",
    "Are internships available for students?",
    "Yes, the college has partnerships with companies that provide internship opportunities for students.",
    "What is the student-to-faculty ratio?",
    "The student-to-faculty ratio is approximately 15:1.",
    "Tell me about the alumni network.",
    "The college has an active alumni network that offers networking opportunities and career support to graduates.",
    "What is the grading system at the college?",
    "The college uses a 10.0 grading scale, where O is equivalent to 10.0 and F is equivalent to less than or equal to 4.0.",
    "Can I transfer credits from another institution?",
    "Credit transfer policies vary. You should contact the college's admissions office for specific details.",
    "Are there study abroad programs available?",
    "Yes, the college offers study abroad programs in partnership with other universities and institutions.",
    "Tell me about the capstone project for Computer Science students.",
    "The capstone project for Computer Science students is a culminating project that allows students to apply their knowledge to real-world problems.",
    "What programming languages are taught in the Computer Science course?",
    "The Computer Science course covers programming languages such as Python, Java, and C++.",
    "Tell me about the class sizes.",
    "Class sizes vary depending on the course and the level of study. Generally, class sizes are kept small to facilitate effective learning.",
    "What is the college's accreditation?",
    "The college is accredited by UGC.",
    "Tell me about the study materials provided to students.",
    "Students are provided with textbooks, lecture notes, and access to online learning resources.",
    "What is the college's mission statement?",
    "The college's mission is to provide quality education and prepare students for successful careers in their chosen fields.",
    "Tell me about the internship placement rate for Mechanical Engineering students.",
    "The college has a high internship placement rate for Mechanical Engineering students, with many students securing internships in renowned companies.",
    "What are the prerequisites for the Mechanical Engineering course?",
    "The prerequisites for the Mechanical Engineering course include a strong foundation in physics and mathematics.",
    "Tell me about the student organizations at the college.",
    "The college has a wide range of student organizations, including academic clubs, cultural clubs, and interest-based clubs.",
    "Are there opportunities for undergraduate research?",
    "Yes, undergraduate students have the opportunity to participate in research projects under the guidance of faculty members.",
    "Tell me about the career services provided by the college.",
    "The college provides career services such as resume writing assistance, job search support, and career counseling.",
    "What is the college's acceptance rate?",
    "The college's acceptance rate varies depending on the course and the number of applications received.",
    "Tell me about the study abroad destinations available for students.",
    "Students can choose from study abroad destinations including UK, Russia, and Germany.",
    "What are the prerequisites for the Electrical Engineering course?",
    "The prerequisites for the Electrical Engineering course include a strong foundation in mathematics and physics.",
    "Tell me about the alumni success stories.",
    "The college has many successful alumni who have made significant contributions in their respective fields.",
    "What is the college's commitment to diversity and inclusion?",
    "The college is committed to fostering a diverse and inclusive campus environment, promoting equal opportunities for all students.",
    "Tell me about the facilities for sports and recreation.",
    "The college has sports facilities including a gymnasium, sports fields, and recreational areas for students to engage in physical activities.",
    "What is the student retention rate?",
    "The college has a high student retention rate, indicating a positive student experience and academic support.",
    "Tell me about the internship opportunities for Computer Science students.",
    "Computer Science students have internship opportunities in industries such as software development, data analysis, and cybersecurity.",
    "What is the average class size?",
    "The average class size is approximately 30 students.",
    "Tell me about the study materials provided for Electrical Engineering students.",
    "Electrical Engineering students are provided with textbooks, lab manuals, and access to simulation software.",
])

# Extract keywords from the user's input
def extract_keywords(query):
    # List of predefined keywords
    keywords = [
        "courses",
        "computer science",
        "electrical engineering",
        "mechanical engineering",
        "syllabus",
        "fees",
        "faculties",
        "admission requirements",
        "contact information",
        "mechanical engineering course",
        "prerequisites",
        "apply for admission",
        "extracurricular activities",
        "career prospects",
        "duration",
        "research opportunities",
        "scholarships",
        "campus facilities",
        "internships",
        "student-to-faculty ratio",
        "alumni network",
        "grading system",
        "transfer credits",
        "study abroad programs",
        "capstone project",
        "programming languages",
        "class sizes",
        "accreditation",
        "study materials",
        "mission statement",
        "internship placement rate",
        "mechanical engineering prerequisites",
        "student organizations",
        "undergraduate research",
        "career services",
        "acceptance rate",
        "study abroad destinations",
        "electrical engineering prerequisites",
        "alumni success stories",
        "diversity and inclusion",
        "sports and recreation facilities",
        "student retention rate",
        "internship opportunities",
        "average class size",
        "study materials for electrical engineering"
    ]

    # Initialize an empty dictionary to store keyword matches
    matched_keywords = {}

    # Check if each keyword exists in the user's query
    for keyword in keywords:
        if keyword in query:
            matched_keywords[keyword] = True
        else:
            matched_keywords[keyword] = False

    return matched_keywords

# Define a function to handle user queries
def handle_query(query):
    # Extract keywords from the query
    keywords = extract_keywords(query)

    # Generate response based on the keywords
    if keywords["courses"]:
        response = "We offer courses in Computer Science, Electrical Engineering, and Mechanical Engineering."
    elif keywords["computer science"]:
        response = "The Computer Science course covers subjects like programming, data structures, and artificial intelligence."
    elif keywords["electrical engineering"]:
        response = "The Electrical Engineering course covers subjects like circuit analysis, digital electronics, and power systems."
    elif keywords["mechanical engineering"]:
        response = "The Mechanical Engineering course covers subjects like thermodynamics, mechanics of materials, and fluid mechanics."
    elif keywords["syllabus"]:
        response = "The syllabus for each course includes a variety of subjects related to the field of study."
    elif keywords["fees"]:
        response = "The fees for each course may vary. Please contact the college's admissions office for detailed fee information."
    elif keywords["faculties"]:
        response = "The faculties for Computer Science are ABC and DEF."
    elif keywords["admission requirements"]:
        response = "The admission requirements for each course may vary. Generally, they include a minimum GPA, standardized test scores, and recommendation letters."
    elif keywords["contact information"]:
        response = "The contact information for the college is as follows: Phone: 123456789, Email: info@examplecollege.edu, Address: 123 College, City, State, Country."
    elif keywords["mechanical engineering course"]:
        response = "The Mechanical Engineering course covers subjects like thermodynamics, mechanics of materials, and fluid mechanics."
    elif keywords["prerequisites"]:
        response = "The prerequisites for each course may vary. Generally, they include a strong foundation in relevant subjects."
    elif keywords["apply for admission"]:
        response = "To apply for admission, you need to fill out an application form, submit required documents, and meet the admission requirements of the chosen course."
    elif keywords["extracurricular activities"]:
        response = "The college offers a range of extracurricular activities including clubs, sports teams, and cultural events."
    elif keywords["career prospects"]:
        response = "Graduates of each course have opportunities in various industries related to their field of study."
    elif keywords["duration"]:
        response = "The duration of each course may vary. Generally, undergraduate courses are four years long."
    elif keywords["research opportunities"]:
        response = "Students have the opportunity to participate in research projects under the guidance of faculty members."
    elif keywords["scholarships"]:
        response = "The college offers various scholarships based on academic merit, financial need, and other criteria. Please contact the college's financial aid office for more information."
    elif keywords["campus facilities"]:
        response = "The campus facilities include state-of-the-art classrooms, laboratories, a library, and recreational areas."
    elif keywords["internships"]:
        response = "Yes, the college has partnerships with companies that provide internship opportunities for students."
    elif keywords["student-to-faculty ratio"]:
        response = "The student-to-faculty ratio is approximately 15:1."
    elif keywords["alumni network"]:
        response = "The college has an active alumni network that offers networking opportunities and career support to graduates."
    elif keywords["grading system"]:
        response = "The college uses a 10.0 grading scale, where O is equivalent to 10.0 and F is equivalent to less than or equal to 4.0."
    elif keywords["transfer credits"]:
        response = "Credit transfer policies vary. You should contact the college's admissions office for specific details."
    elif keywords["study abroad programs"]:
        response = "Yes, the college offers study abroad programs in partnership with other universities and institutions."
    elif keywords["capstone project"]:
        response = "The capstone project is a culminating project that allows students to apply their knowledge to real-world problems."
    elif keywords["programming languages"]:
        response = "The courses cover programming languages such as Python, Java, and C++."
    elif keywords["class sizes"]:
        response = "Class sizes vary depending on the course and the level of study. Generally, class sizes are kept small to facilitate effective learning."
    elif keywords["accreditation"]:
        response = "The college is accredited by UGC."
    elif keywords["study materials"]:
        response = "Students are provided with textbooks, lecture notes, and access to online learning resources."
    elif keywords["mission statement"]:
        response = "The college's mission is to provide quality education and prepare students for successful careers in their chosen fields."
    elif keywords["internship placement rate"]:
        response = "The college has a high internship placement rate for students."
    elif keywords["mechanical engineering prerequisites"]:
        response = "The prerequisites for the Mechanical Engineering course include a strong foundation in physics and mathematics."
    elif keywords["student organizations"]:
        response = "The college has a wide range of student organizations, including academic clubs, cultural clubs, and interest-based clubs."
    elif keywords["undergraduate research"]:
        response = "Yes, undergraduate students have the opportunity to participate in research projects under the guidance of faculty members."
    elif keywords["career services"]:
        response = "The college provides career services such as resume writing assistance, job search support, and career counseling."
    elif keywords["acceptance rate"]:
        response = "The college's acceptance rate varies depending on the course and the number of applications received."
    elif keywords["study abroad destinations"]:
        response = "Students can choose from study abroad destinations including UK, Russia, and Germany."
    elif keywords["electrical engineering prerequisites"]:
        response = "The prerequisites for the Electrical Engineering course include a strong foundation in mathematics and physics."
    elif keywords["alumni success stories"]:
        response = "The college has many successful alumni who have made significant contributions in their respective fields."
    elif keywords["diversity and inclusion"]:
        response = "The college is committed to fostering a diverse and inclusive campus environment, promoting equal opportunities for all students."
    elif keywords["sports and recreation facilities"]:
        response = "The college has sports facilities including a gymnasium, sports fields, and recreational areas for students to engage in physical activities."
    elif keywords["student retention rate"]:
        response = "The college has a high student retention rate, indicating a positive student experience and academic support."
    elif keywords["internship opportunities"]:
        response = "Students have internship opportunities in various industries related to their field of study."
    elif keywords["average class size"]:
        response = "The average class size is approximately 30 students."
    elif keywords["study materials for electrical engineering"]:
        response = "Electrical Engineering students are provided with textbooks, lab manuals, and access to simulation software."
    else:
        response = "I'm sorry, I couldn't understand your query. Please try asking in a different way or contact the college's admissions office for more information."

    return response

# Main loop to get user input and generate responses
while True:
    user_input = input("User: ")
    if user_input.lower() == "exit":
        break

    response = handle_query(user_input)
    print("CollegeAdmissionBot:", response)
# Out:
# Training ai.yml: [#                   ] 4%
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\harsh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Training ai.yml: [####################] 100%
# Training botprofile.yml: [####################] 100%
# Training computers.yml: [####################] 100%
# Training conversations.yml: [####################] 100%
# Training emotion.yml: [####################] 100%
# Training food.yml: [####################] 100%
# Training gossip.yml: [####################] 100%
# ...
